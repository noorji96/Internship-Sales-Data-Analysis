# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 
import calendar

# %%
data=pd.read_excel(r'C:\\Users\\hanfo\\Desktop\\Noorji\\SALESDATA.xlsx', engine="openpyxl",parse_dates=['DateKey','Invoice Date', 'Promised Delivery Date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65241 entries, 0 to 65240
# Data columns (total 25 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Unnamed: 0                        65241 non-null  int64
#  1   CustKey                           65241 non-null  int64
#  2   DateKey                           65241 non-null  datetime64[ns]
#  3   Discount Amount                   65241 non-null  float64
#  4   Invoice Date                      65241 non-null  datetime64[ns]
#  5   Invoice Number                    65241 non-null  int64
#  6   Item Number                       65241 non-null  object
#  7   Item                              65241 non-null  object
#  8   Line Number                       65241 non-null  int64
#  9   List Price                        65241 non-null  float64
#  10  Order Number                      65241 non-null  int64
# ...

# %%
data.head()
# Out:
#    Unnamed: 0   CustKey    DateKey  Discount Amount Invoice Date  \
# 0           1  10002220 2017-07-14          368.790   2017-07-14
# 1           2  10002220 2017-10-17          109.730   2017-10-17
# 2           4  10004516 2017-05-27        96627.940   2017-05-27
# 3           6  10007866 2017-09-03          371.014   2017-09-03
# 4           7  10009356 2017-06-18          608.080   2017-06-18
#
#    Invoice Number Item Number                             Item  Line Number  \
# 0          100233       20910               Moms Sliced Turkey         1000
# 1          116165       38076  Cutting Edge Foot-Long Hot Dogs         1000
# 2          103341       60776             High Top Sweet Onion         1000
# 3          100403       20910               Moms Sliced Turkey         2000
# 4          105481       62550                 Tell Tale Garlic        29000
#
#    List Price  ...  Sales Margin Amount Sales Price  Sales Quantity  \
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                          0
# CustKey                             0
# DateKey                             0
# Discount Amount                     0
# Invoice Date                        0
# Invoice Number                      0
# Item Number                         0
# Item                                0
# Line Number                         0
# List Price                          0
# Order Number                        0
# Promised Delivery Date              0
# Sales Amount                        0
# Sales Amount Based on List Price    0
# Sales Cost Amount                   0
# Sales Margin Amount                 0
# Sales Price                         0
# Sales Quantity                      0
# Sales Rep                           0
# U/M                                 0
# invoice_year                        0
# invoice_quarter                     0
# invoice_day                         0
# invoice_month                       0
# Month                               0
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'CustKey', 'DateKey', 'Discount Amount', 'Invoice Date',
#        'Invoice Number', 'Item Number', 'Item', 'Line Number', 'List Price',
#        'Order Number', 'Promised Delivery Date', 'Sales Amount',
#        'Sales Amount Based on List Price', 'Sales Cost Amount',
#        'Sales Margin Amount', 'Sales Price', 'Sales Quantity', 'Sales Rep',
#        'U/M', 'invoice_year', 'invoice_quarter', 'invoice_day',
#        'invoice_month', 'Month'],
#       dtype='object')

# %%
data.describe()
# Out:
#          Unnamed: 0       CustKey  Discount Amount  Invoice Number  \
# count  65241.000000  6.524100e+04     65241.000000    65241.000000
# mean   32649.052820  1.001770e+07      1857.310923   216292.785242
# std    18844.645788  7.175846e+03      9039.535784    94982.018695
# min        1.000000  1.000045e+07   -255820.800000   100034.000000
# 25%    16324.000000  1.001272e+07       246.280000   117969.000000
# 50%    32654.000000  1.001966e+07       442.200000   222904.000000
# 75%    48970.000000  1.002351e+07      1001.500000   314325.000000
# max    65281.000000  1.002758e+07    343532.660000   332842.000000
#
#          Line Number    List Price   Order Number   Sales Amount  \
# count   65241.000000  65241.000000   65241.000000   65241.000000
# mean    23725.043178    515.016834  180567.610122    2853.121051
# std     32669.565014    449.144896   67612.238675   15169.020896
# min      1000.000000      0.000000  100838.000000     200.010000
# ...

# %%
data['invoice_year']=data['Invoice Date'].dt.year
data['invoice_quarter']=data['Invoice Date'].dt.quarter
data['invoice_day']=data['Invoice Date'].dt.day

# %%
data['invoice_year'].value_counts()
# Out:
# 2017    30534
# 2019    28021
# 2018     6686
# Name: invoice_year, dtype: int64

# %%
data['invoice_month']=data['Invoice Date'].dt.month

# %%
data['invoice_month']
# Out:
# 0         7
# 1        10
# 2         5
# 3         9
# 4         6
#          ..
# 65236     3
# 65237     3
# 65238     3
# 65239     3
# 65240     3
# Name: invoice_month, Length: 65241, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65241 entries, 0 to 65240
# Data columns (total 25 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Unnamed: 0                        65241 non-null  int64
#  1   CustKey                           65241 non-null  int64
#  2   DateKey                           65241 non-null  datetime64[ns]
#  3   Discount Amount                   65241 non-null  float64
#  4   Invoice Date                      65241 non-null  datetime64[ns]
#  5   Invoice Number                    65241 non-null  int64
#  6   Item Number                       65241 non-null  object
#  7   Item                              65241 non-null  object
#  8   Line Number                       65241 non-null  int64
#  9   List Price                        65241 non-null  float64
#  10  Order Number                      65241 non-null  int64
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                          0
# CustKey                             0
# DateKey                             0
# Discount Amount                     0
# Invoice Date                        0
# Invoice Number                      0
# Item Number                         0
# Item                                0
# Line Number                         0
# List Price                          0
# Order Number                        0
# Promised Delivery Date              0
# Sales Amount                        0
# Sales Amount Based on List Price    0
# Sales Cost Amount                   0
# Sales Margin Amount                 0
# Sales Price                         0
# Sales Quantity                      0
# Sales Rep                           0
# U/M                                 0
# invoice_year                        0
# invoice_quarter                     0
# invoice_day                         0
# invoice_month                       0
# Month                               0
# ...

# %%
data.isna().sum()
# Out:
# Unnamed: 0                          0
# CustKey                             0
# DateKey                             0
# Discount Amount                     0
# Invoice Date                        0
# Invoice Number                      0
# Item Number                         0
# Item                                0
# Line Number                         0
# List Price                          0
# Order Number                        0
# Promised Delivery Date              0
# Sales Amount                        0
# Sales Amount Based on List Price    0
# Sales Cost Amount                   0
# Sales Margin Amount                 0
# Sales Price                         0
# Sales Quantity                      0
# Sales Rep                           0
# U/M                                 0
# invoice_year                        0
# invoice_quarter                     0
# invoice_day                         0
# invoice_month                       0
# Month                               0
# ...

# %%
data.dropna(subset=['Discount Amount','Sales Price', 'Item Number'],axis=0,inplace=True)

# %%
data.isna().sum()
# Out:
# Unnamed: 0                          0
# CustKey                             0
# DateKey                             0
# Discount Amount                     0
# Invoice Date                        0
# Invoice Number                      0
# Item Number                         0
# Item                                0
# Line Number                         0
# List Price                          0
# Order Number                        0
# Promised Delivery Date              0
# Sales Amount                        0
# Sales Amount Based on List Price    0
# Sales Cost Amount                   0
# Sales Margin Amount                 0
# Sales Price                         0
# Sales Quantity                      0
# Sales Rep                           0
# U/M                                 0
# invoice_year                        0
# invoice_quarter                     0
# invoice_day                         0
# invoice_month                       0
# Month                               0
# ...

# %%
plt.figure(figsize=(12,10))
sns.heatmap(data.corr(method='pearson'),annot=True, vmin=-1, vmax=1, cmap='turbo')
# Out:
# C:\Users\hanfo\AppData\Local\Temp\ipykernel_22428\2256105521.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(method='pearson'),annot=True, vmin=-1, vmax=1, cmap='turbo')
# <Axes: >

# %% [markdown]
# Sales Amount based onlist Price is highly co-related with Sales amount,Sales cost Amount, Sales margin amount
# Sales price is highly co-related with list price
# Discount Amount is less co-related with sales qunatity

# %%
data['Item']
# Out:
# 0                     Moms Sliced Turkey
# 1        Cutting Edge Foot-Long Hot Dogs
# 2                   High Top Sweet Onion
# 3                     Moms Sliced Turkey
# 4                       Tell Tale Garlic
#                       ...
# 65236                   High Top Oranges
# 65237              Landslide White Sugar
# 65238                  Moms Potato Salad
# 65239       Better Fancy Canned Sardines
# 65240                  Imagine Popsicles
# Name: Item, Length: 65241, dtype: object

# %%
data.Item.value_counts()
# Out:
# Better Fancy Canned Sardines    1648
# Ebony Prepared Salad            1471
# Moms Sliced Turkey              1192
# Imagine Popsicles               1191
# Discover Manicotti              1126
#                                 ...
# Ebony Mixed Nuts                  10
# Tell Tale Fuji Apples             10
# Great Blueberry Muffins           10
# Golden Blueberry Waffles          10
# Carlson Strawberry Yogurt         10
# Name: Item, Length: 466, dtype: int64

# %%
Items= data['Item'].value_counts(ascending  = False)
Items
# Out:
# Better Fancy Canned Sardines    1648
# Ebony Prepared Salad            1471
# Moms Sliced Turkey              1192
# Imagine Popsicles               1191
# Discover Manicotti              1126
#                                 ...
# Ebony Mixed Nuts                  10
# Tell Tale Fuji Apples             10
# Great Blueberry Muffins           10
# Golden Blueberry Waffles          10
# Carlson Strawberry Yogurt         10
# Name: Item, Length: 466, dtype: int64

# %%
items_lessthan10 = Items[Items<10]
items_lessthan10
# Out:
# Series([], Name: Item, dtype: int64)

# %% [markdown]
# # To Reduce the noise in data , grouped the items with values less than 10 as "others"

# %%
def handle_items(value):
    if(value in items_lessthan10):
        return 'others'
    else:
        return value
        
data['Item'] = data['Item'].apply( handle_items)
data['Item'].value_counts()
# Out:
# Better Fancy Canned Sardines    1648
# Ebony Prepared Salad            1471
# Moms Sliced Turkey              1192
# Imagine Popsicles               1191
# Discover Manicotti              1126
#                                 ...
# Ebony Mixed Nuts                  10
# Tell Tale Fuji Apples             10
# Great Blueberry Muffins           10
# Golden Blueberry Waffles          10
# Carlson Strawberry Yogurt         10
# Name: Item, Length: 466, dtype: int64

# %%
data.describe()
# Out:
#          Unnamed: 0       CustKey  Discount Amount  Invoice Number  \
# count  65241.000000  6.524100e+04     65241.000000    65241.000000
# mean   32649.052820  1.001770e+07      1857.310923   216292.785242
# std    18844.645788  7.175846e+03      9039.535784    94982.018695
# min        1.000000  1.000045e+07   -255820.800000   100034.000000
# 25%    16324.000000  1.001272e+07       246.280000   117969.000000
# 50%    32654.000000  1.001966e+07       442.200000   222904.000000
# 75%    48970.000000  1.002351e+07      1001.500000   314325.000000
# max    65281.000000  1.002758e+07    343532.660000   332842.000000
#
#          Line Number    List Price   Order Number   Sales Amount  \
# count   65241.000000  65241.000000   65241.000000   65241.000000
# mean    23725.043178    515.016834  180567.610122    2853.121051
# std     32669.565014    449.144896   67612.238675   15169.020896
# min      1000.000000      0.000000  100838.000000     200.010000
# ...

# %%
data.head()
# Out:
#    Unnamed: 0   CustKey    DateKey  Discount Amount Invoice Date  \
# 0           1  10002220 2017-07-14          368.790   2017-07-14
# 1           2  10002220 2017-10-17          109.730   2017-10-17
# 2           4  10004516 2017-05-27        96627.940   2017-05-27
# 3           6  10007866 2017-09-03          371.014   2017-09-03
# 4           7  10009356 2017-06-18          608.080   2017-06-18
#
#    Invoice Number Item Number                             Item  Line Number  \
# 0          100233       20910               Moms Sliced Turkey         1000
# 1          116165       38076  Cutting Edge Foot-Long Hot Dogs         1000
# 2          103341       60776             High Top Sweet Onion         1000
# 3          100403       20910               Moms Sliced Turkey         2000
# 4          105481       62550                 Tell Tale Garlic        29000
#
#    List Price  ...  Sales Margin Amount Sales Price  Sales Quantity  \
# ...

# %% [markdown]
# List Price=Listed price in item;
# Discount price=List price-Sales Price;
# Discount Amount=Discount price*sales Quantity

# %%
data['Month'] = data['invoice_month'].apply(lambda x: calendar.month_abbr[x])

# %% [markdown]
# # To Find Out The Day Difference Beween Promised Delivery Date and Invoice Date

# %%
data['DD'] =(data['Promised Delivery Date'] - data['Invoice Date']) / np.timedelta64(1, 'D')
data['DD'] = data['DD'].astype(int)

# %%
data['DD'] .value_counts(ascending  = False)
# Out:
#  0       51641
# -1        5572
#  1        3481
# -2        1016
# -3         994
#  3         932
# -4         638
# -5         249
# -7         236
#  5          81
#  6          70
# -6          64
# -33         51
# -2925       50
#  7          30
#  8          27
#  2          13
# -25         12
# -32          9
# -16          7
# -14          6
# -61          6
# -12          5
# -8           5
# -21          4
# -11          4
# -9           4
# -29          4
#  4           3
# -19          3
# -34          3
# -48          2
# -49          2
# -15          2
# -27          2
#  14          2
# -3653        2
#  9           1
# -28          1
# -17          1
#  18          1
# -10          1
# -26          1
# -18          1
# -2941        1
# -2914        1
# Name: DD, dtype: int64

# %%
data['Sales Quantity'].sum()
# Out:
# 2942807

# %%
data['Discount Amount'] .describe()
# Out:
# count     65241.000000
# mean       1857.310923
# std        9039.535784
# min     -255820.800000
# 25%         246.280000
# 50%         442.200000
# 75%        1001.500000
# max      343532.660000
# Name: Discount Amount, dtype: float64

# %%
dd_morethan_month = data_DD[data_DD<-30]
dd_morethan_month
# Out:
# Series([], Name: dd2, dtype: int64)

# %%
data['List Price'] .value_counts(ascending  = False)
# Out:
# 298.00     1508
# 1431.23    1426
# 966.44     1192
# 1275.10    1126
# 192.34     1041
#            ...
# 200.80        1
# 3.22          1
# 206.12        1
# 29.37         1
# 205.00        1
# Name: List Price, Length: 1062, dtype: int64

# %%
Yearly_Sales =data.groupby('invoice_year').sum().reset_index()
sns.catplot(y = 'Sales Amount', x = 'invoice_year', data = Yearly_Sales, palette='Blues',kind="bar")
plt.xlabel('Year')
plt.ylabel('Sales Amount')
plt.title('Yearly Sales')
Yearly_Sales[['invoice_year', 'Sales Amount']]
# Out:
# C:\Users\hanfo\AppData\Local\Temp\ipykernel_22428\2545606931.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   Yearly_Sales =data.groupby('invoice_year').sum().reset_index()
#    invoice_year  Sales Amount
# 0          2017   87416407.83
# 1          2018   20817471.00
# 2          2019   77906591.65

# %%
Monthly_Sales =data.groupby('Month').sum().reset_index()
sns.catplot(y = 'Sales Amount', x = 'Month', data = Monthly_Sales, palette='Blues',kind="bar")
plt.xlabel('Year')
plt.ylabel('Sales Amount')
plt.title('Monthly Sales')
Monthly_Sales[['Month', 'Sales Amount']]
# Out:
# C:\Users\hanfo\AppData\Local\Temp\ipykernel_22428\3071853566.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   Monthly_Sales =data.groupby('Month').sum().reset_index()
#    Month  Sales Amount
# 0    Apr   12111896.58
# 1    Aug   14587873.63
# 2    Dec   14516466.67
# 3    Feb   20497349.91
# 4    Jan   19471739.54
# 5    Jul   13285760.98
# 6    Jun   15828486.18
# 7    Mar   21714172.68
# 8    May   11043338.72
# 9    Nov   13792860.99
# 10   Oct   12826858.62
# 11   Sep   16463665.98

# %%
plt.figure(figsize=(17,6))
plt.pie('Sales Amount',labels='invoice_year',data=Yearly_Sales,
        autopct='%1.2f%%',shadow=True,startangle=90)
plt.axis('equal')
plt.title('Sales Contribution')
plt.legend(round(Yearly_Sales['Sales Amount'],2), loc=7, fontsize = 'xx-large')
plt.show()

# %%
Yearly_Monthwise_Sales = data.groupby(['invoice_year','Month']).sum().reset_index()
# Out:
# C:\Users\hanfo\AppData\Local\Temp\ipykernel_22428\3132781804.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   Yearly_Monthwise_Sales = data.groupby(['invoice_year','Month']).sum().reset_index()

# %%
sns.relplot(x ='Month',y = 'Sales Amount', data=Yearly_Monthwise_Sales,height=5,
            kind = 'line', aspect = 1, col = 'invoice_year')
plt.xlabel('Month')
plt.ylabel('Sales Amount')
# Out:
# Text(1012.4490740740741, 0.5, 'Sales Amount')
